# %%
# %matplotlib inline
import torchvision.datasets as dataset
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset
import matplotlib.pyplot as plt
import torchvision.utils
import numpy as np
import random
from PIL import Image
import torch
from torch.autograd import Variable
import PIL.ImageOps    
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

# %%
pwd
# Out:
# '/Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master'

# %%
class ConfigClass():
    train_dir = '/Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/'
    test_dir = '/Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/testing/'   
    train_batch_size = 64
    train_num_epochs = 100

# %%
class SiameseDataset(Dataset):
    
    def __init__(self, image_folder, transform = None, invert = False):
        self.image_folder = image_folder
        self.transform = transform
        self.invert = invert
        
    def __getitem__(self, index):
        sample_1 = random.choice(self.image_folder.imgs)
        same_class = random.randint(0, 1)
        
        if same_class:
            while True:
                sample_2 = random.choice(self.image_folder.imgs)
                if sample_1[1] == sample_2[1]:
                    break
        else:
            while True:
                sample_2 = random.choice(self.image_folder.imgs)
                if sample_1[1] != sample_2[1]:
                    break
        
        img_1 = Image.open(sample_1[0]).convert("L")
        img_2 = Image.open(sample_2[0]).convert("L")
        
        if self.invert:
            img_1 = PIL.ImageOps.invert(img_1)
            img_2 = PIL.ImageOps.invert(img_2)
        
        if self.transform:
            img_1 = self.transform(img_1)
            img_2 = self.transform(img_2)
            
        return img_1, img_2, torch.from_numpy(np.array([int(sample_1[1] != sample_2[1])], dtype = np.float32))
    
    def __len__(self):
        return len(self.image_folder.imgs)

# %%
import os

train_dir = ConfigClass.train_dir
if os.path.isdir(train_dir):
    print(f"The train_dir '{train_dir}' exists and is accessible")
else:
    print(f"The train_dir '{train_dir}' does not exist or is not accessible")
# Out:
# The train_dir '/Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/' exists and is accessible

# %%
try:
    SiameseDataset(image_folder=image_folder, 
                                 transform=transforms.Compose([transforms.Resize((100, 100)), transforms.ToTensor()]), 
                                 invert=False)
except Exception as e:
    print("An error occurred while accessing the image folder: ", e)
# Out:
# An error occurred while accessing the image folder:  name 'image_folder' is not defined

# %%
image_folder = dataset.ImageFolder(root=ConfigClass.train_dir)
siamese_dataset = SiameseDataset(image_folder=image_folder, 
                                 transform=transforms.Compose([transforms.Resize((100, 100)), transforms.ToTensor()]), 
                                 invert=False)

# %%
import numpy as np
import os
from PIL import Image

image_folder = dataset.ImageFolder(root=ConfigClass.train_dir)

for image_path, _ in image_folder.samples:
    with Image.open(image_path) as img:
        # Check if the image is grayscale
        if img.mode == 'L':
            print(f"{image_path} is a grayscale image.")
        # Check if the image is binary
        elif np.array(img).max() <= 1:
            print(f"{image_path} is a binary image.")
        # Otherwise, assume the image is color
        else:
            print(f"{image_path} is a color image.")
# Out:
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s1/1.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s1/1.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s1/10.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s1/10.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s1/2.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s1/2.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s1/3.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s1/3.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s1/4.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s1/4.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s1/5.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s1/5.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s1/6.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s1/6.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s1/7.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s1/7.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s1/8.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s1/8.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s1/9.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s1/9.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s10/1.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s10/1.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s10/10.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s10/10.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s10/2.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s10/2.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s10/3.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s10/3.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s10/4.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s10/4.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s10/5.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s10/5.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s10/6.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s10/6.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s10/7.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s10/7.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s10/8.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s10/8.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s10/9.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s10/9.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s11/1.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s11/1.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s11/10.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s11/10.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s11/2.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s11/2.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s11/3.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s11/3.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s11/4.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s11/4.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s11/5.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s11/5.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s11/6.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s11/6.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s11/7.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s11/7.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s11/8.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s11/8.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s11/9.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s11/9.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s12/1.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s12/1.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s12/10.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s12/10.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s12/2.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s12/2.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s12/3.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s12/3.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s12/4.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s12/4.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s12/5.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s12/5.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s12/6.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s12/6.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s12/7.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s12/7.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s12/8.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s12/8.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s12/9.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s12/9.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s13/1.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s13/1.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s13/10.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s13/10.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s13/2.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s13/2.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s13/3.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s13/3.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s13/4.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s13/4.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s13/5.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s13/5.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s13/6.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s13/6.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s13/7.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s13/7.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s13/8.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s13/8.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s13/9.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s13/9.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s14/1.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s14/1.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s14/10.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s14/10.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s14/2.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s14/2.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s14/3.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s14/3.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s14/4.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s14/4.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s14/5.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s14/5.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s14/6.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s14/6.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s14/7.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s14/7.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s14/8.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s14/8.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s14/9.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s14/9.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s15/1.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s15/1.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s15/10.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s15/10.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s15/2.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s15/2.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s15/3.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s15/3.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s15/4.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s15/4.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s15/5.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s15/5.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s15/6.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s15/6.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s15/7.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s15/7.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s15/8.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s15/8.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s15/9.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s15/9.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s16/1.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s16/1.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s16/10.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s16/10.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s16/2.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s16/2.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s16/3.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s16/3.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s16/4.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s16/4.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s16/5.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s16/5.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s16/6.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s16/6.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s16/7.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s16/7.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s16/8.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s16/8.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s16/9.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s16/9.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s17/1.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s17/1.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s17/10.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s17/10.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s17/2.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s17/2.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s17/3.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s17/3.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s17/4.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s17/4.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s17/5.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s17/5.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s17/6.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s17/6.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s17/7.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s17/7.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s17/8.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s17/8.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s17/9.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s17/9.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s18/1.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s18/1.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s18/10.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s18/10.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s18/2.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s18/2.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s18/3.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s18/3.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s18/4.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s18/4.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s18/5.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s18/5.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s18/6.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s18/6.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s18/7.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s18/7.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s18/8.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s18/8.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s18/9.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s18/9.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s19/1.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s19/1.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s19/10.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s19/10.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s19/2.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s19/2.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s19/3.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s19/3.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s19/4.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s19/4.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s19/5.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s19/5.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s19/6.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s19/6.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s19/7.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s19/7.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s19/8.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s19/8.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s19/9.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s19/9.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s2/1.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s2/1.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s2/10.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s2/10.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s2/2.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s2/2.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s2/3.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s2/3.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s2/4.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s2/4.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s2/5.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s2/5.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s2/6.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s2/6.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s2/7.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s2/7.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s2/8.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s2/8.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s2/9.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s2/9.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s20/1.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s20/1.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s20/10.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s20/10.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s20/2.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s20/2.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s20/3.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s20/3.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s20/4.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s20/4.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s20/5.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s20/5.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s20/6.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s20/6.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s20/7.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s20/7.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s20/8.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s20/8.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s20/9.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s20/9.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s21/1.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s21/1.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s21/10.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s21/10.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s21/2.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s21/2.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s21/3.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s21/3.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s21/4.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s21/4.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s21/5.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s21/5.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s21/6.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s21/6.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s21/7.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s21/7.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s21/8.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s21/8.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s21/9.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s21/9.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s22/1.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s22/1.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s22/10.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s22/10.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s22/2.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s22/2.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s22/3.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s22/3.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s22/4.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s22/4.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s22/5.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s22/5.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s22/6.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s22/6.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s22/7.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s22/7.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s22/8.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s22/8.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s22/9.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s22/9.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s23/1.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s23/1.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s23/10.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s23/10.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s23/2.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s23/2.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s23/3.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s23/3.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s23/4.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s23/4.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s23/5.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s23/5.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s23/6.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s23/6.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s23/7.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s23/7.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s23/8.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s23/8.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s23/9.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s23/9.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s24/1.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s24/1.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s24/10.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s24/10.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s24/2.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s24/2.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s24/3.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s24/3.pgm.png is a grayscale image.
# ...
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s38/5.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s38/6.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s38/6.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s38/7.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s38/7.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s38/8.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s38/8.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s38/9.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s38/9.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s39/1.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s39/1.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s39/10.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s39/10.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s39/2.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s39/2.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s39/3.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s39/3.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s39/4.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s39/4.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s39/5.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s39/5.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s39/6.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s39/6.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s39/7.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s39/7.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s39/8.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s39/8.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s39/9.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s39/9.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s4/1.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s4/1.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s4/10.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s4/10.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s4/2.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s4/2.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s4/3.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s4/3.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s4/4.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s4/4.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s4/5.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s4/5.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s4/6.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s4/6.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s4/7.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s4/7.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s4/8.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s4/8.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s4/9.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s4/9.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s40/1.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s40/1.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s40/10.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s40/10.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s40/2.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s40/2.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s40/3.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s40/3.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s40/4.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s40/4.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s40/5.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s40/5.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s40/6.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s40/6.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s40/7.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s40/7.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s40/8.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s40/8.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s40/9.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s40/9.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s8/1.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s8/1.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s8/10.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s8/10.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s8/2.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s8/2.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s8/3.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s8/3.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s8/4.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s8/4.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s8/5.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s8/5.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s8/6.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s8/6.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s8/7.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s8/7.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s8/8.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s8/8.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s8/9.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s8/9.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s9/1.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s9/1.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s9/10.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s9/10.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s9/2.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s9/2.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s9/3.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s9/3.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s9/4.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s9/4.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s9/5.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s9/5.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s9/6.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s9/6.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s9/7.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s9/7.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s9/8.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s9/8.pgm.png is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s9/9.pgm is a grayscale image.
# /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/s9/9.pgm.png is a grayscale image.

# %%
print("Image Folder: ", image_folder)
print("Siamese Dataset: ", siamese_dataset)
# Out:
# Image Folder:  Dataset ImageFolder
#     Number of datapoints: 740
#     Root location: /Users/mounikaganjikunta/Desktop/Spring 2023/Project/Face-Similarity-Siamese-Network-master/data/faces/training/
# Siamese Dataset:  <__main__.SiameseDataset object at 0x7fadf35a03a0>

# %%
def imshow(img, text=None):
    np_img = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic', fontweight='bold', bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(np_img, (1, 2, 0)))
    plt.show()    

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %%
dataloader = DataLoader(siamese_dataset, shuffle=True, num_workers=0, batch_size=8)
data_iter = iter(dataloader)
vis_batch = next(data_iter)
merged = torch.cat((vis_batch[0], vis_batch[1]), 0)
imshow(torchvision.utils.make_grid(merged))
vis_batch[2].numpy()
# Out:
# array([[0.],
#        [0.],
#        [1.],
#        [0.],
#        [0.],
#        [0.],
#        [1.],
#        [0.]], dtype=float32)

# %%
class SiameseNetwork(nn.Module):
    def __init__(self):
        super(SiameseNetwork, self).__init__()
        
        self.reflection_pad = nn.ReflectionPad2d(1)
        self.conv1 = nn.Conv2d(1, 4, kernel_size=3)
        self.conv2 = nn.Conv2d(4, 8, kernel_size=3)
        self.conv3 = nn.Conv2d(8, 8, kernel_size=3) 
        self.relu = nn.ReLU(inplace=True)
        self.batch_norm1 = nn.BatchNorm2d(4)
        self.batch_norm2 = nn.BatchNorm2d(8) 
        self.fc1 = nn.Linear(8 * 100 * 100, 500)
        self.fc2 = nn.Linear(500, 500)
        self.fc3 = nn.Linear(500, 5)
        
    def forward_one_branch(self, x):
        x = self.batch_norm1(self.relu(self.conv1(self.reflection_pad(x))))
        x = self.batch_norm2(self.relu(self.conv2(self.reflection_pad(x))))        
        x = self.batch_norm2(self.relu(self.conv3(self.reflection_pad(x))))   
        x = x.view(x.size()[0], -1)
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))        
        x = self.fc3(x)
        
        return x
        
    def forward(self, input1, input2):
        output1 = self.forward_one_branch(input1)
        output2 = self.forward_one_branch(input2)     
        
        return output1, output2

# %%
class ContrastiveLoss(torch.nn.Module):
    
    def __init__(self, margin=0.5, threshold=0.4):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin
        self.threshold = threshold
        
    def forward(self, output1, output2, label):
        
        # Compute the covariance matrix of output1 and output2
        cov = torch.cat([output1, output2], dim=0).T @ torch.cat([output1, output2], dim=0)
        cov = torch.inverse(cov + 1e-6 * torch.eye(cov.shape[0]).to(output1.device))  
        
        # Compute Mahalanobis distance
        diff = output1 - output2
        distance = torch.sqrt(torch.sum(torch.matmul(diff, cov) * diff, dim=1, keepdim=True))
        
        # Compute contrastive loss
        contrastive_loss = torch.mean((1 - label) * torch.pow(distance, 2) 
                                      + (label) * torch.pow(torch.clamp(self.margin - distance, min=0.0), 2))
        
        return contrastive_loss

# %%
print(torch.version.cuda)
# Out:
# None

# %%
pip install torch torchvision torchaudio -f https://download.pytorch.org/whl/cuXX/torch_stable.html
# Out:
#   File "/var/folders/db/l270zpx17c5dwrrjphch31wc0000gn/T/ipykernel_6756/3878635041.py", line 1
#     pip install torch torchvision torchaudio -f https://download.pytorch.org/whl/cuXX/torch_stable.html
#         ^
# SyntaxError: invalid syntax

# %%
# Define your data loader
dataloader = DataLoader(siamese_dataset, shuffle=True, num_workers=0, batch_size=ConfigClass.train_batch_size)

# Instantiate the model, loss function, and optimizer
model = SiameseNetwork().cpu()
criterion = ContrastiveLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0005)

# Define some variables for tracking progress
counter = []
loss_history = []
iteration = 0

# %%
# Train the model
for epoch in range(ConfigClass.train_num_epochs):
    for i, data in enumerate(dataloader, 0):
        input1, input2, label = data
        input1, input2, label = input1.cpu(), input2.cpu(), label.cpu()
        
        optimizer.zero_grad()
        output1, output2 = model(input1, input2)
        contrastive_loss = criterion(output1, output2, label)
        contrastive_loss.backward()
        optimizer.step()
        
        # Log the loss and iteration
        if (i+1) % 10 == 0:
            print("Epoch: {} \t Loss: {}".format(epoch, contrastive_loss.item()))
            iteration += 10
            loss_history.append(contrastive_loss.item())
            counter.append(iteration)

# Visualize the training loss
show_plot(counter, loss_history)
# Out:
# Epoch: 0 	 Loss: 0.050528015941381454
# Epoch: 1 	 Loss: 0.046220988035202026
# Epoch: 2 	 Loss: 0.04336501285433769
# Epoch: 3 	 Loss: 0.02925114519894123
# Epoch: 4 	 Loss: 0.028915870934724808
# Epoch: 5 	 Loss: 0.026037275791168213
# Epoch: 6 	 Loss: 0.027496661990880966
# Epoch: 7 	 Loss: 0.03844964876770973
# Epoch: 8 	 Loss: 0.023693401366472244
# Epoch: 9 	 Loss: 0.02986447699368
# Epoch: 10 	 Loss: 0.022772841155529022
# Epoch: 11 	 Loss: 0.022342853248119354
# Epoch: 12 	 Loss: 0.026894479990005493
# Epoch: 13 	 Loss: 0.027758046984672546
# Epoch: 14 	 Loss: 0.032875336706638336
# Epoch: 15 	 Loss: 0.029378540813922882
# Epoch: 16 	 Loss: 0.026638103649020195
# Epoch: 17 	 Loss: 0.02343437820672989
# Epoch: 18 	 Loss: 0.023413093760609627
# Epoch: 19 	 Loss: 0.019887151196599007
# Epoch: 20 	 Loss: 0.03523539751768112
# Epoch: 21 	 Loss: 0.03118465654551983
# Epoch: 22 	 Loss: 0.025071866810321808
# Epoch: 23 	 Loss: 0.030528800562024117
# Epoch: 24 	 Loss: 0.030955182388424873
# Epoch: 82 	 Loss: 0.023432433605194092
# Epoch: 83 	 Loss: 0.0309690423309803
# Epoch: 84 	 Loss: 0.027385501191020012
# Epoch: 85 	 Loss: 0.023736421018838882
# Epoch: 86 	 Loss: 0.03046162612736225
# Epoch: 87 	 Loss: 0.0250425823032856
# Epoch: 88 	 Loss: 0.02232908084988594
# Epoch: 89 	 Loss: 0.02637402154505253
# Epoch: 90 	 Loss: 0.024520661681890488
# Epoch: 91 	 Loss: 0.029564175754785538
# Epoch: 92 	 Loss: 0.026491941884160042
# Epoch: 93 	 Loss: 0.026470130309462547
# Epoch: 94 	 Loss: 0.030196616426110268
# Epoch: 95 	 Loss: 0.026254665106534958
# Epoch: 96 	 Loss: 0.03300272673368454
# Epoch: 97 	 Loss: 0.03455584868788719
# Epoch: 98 	 Loss: 0.029288731515407562
# Epoch: 99 	 Loss: 0.0265568345785141

# %%
import torch.nn.functional as F
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

test_folder = dataset.ImageFolder(root=ConfigClass.test_dir)
siamese_dataset = SiameseDataset(image_folder=test_folder, 
                                 transform=transforms.Compose([transforms.Resize((100, 100)), transforms.ToTensor()]), 
                                 invert=False)

dataloader = DataLoader(siamese_dataset, num_workers=0, batch_size=1, shuffle=True)
data_iter = iter(dataloader)

threshold = 1.5
correct = 0
total = 0
y_true = None
y_pred = None

for i in range(10):
    img0, _, _ = next(data_iter)
    _, img1, label = next(data_iter)
    merged = torch.cat((img0,img1), 0)
    
    output1, output2 = model(Variable(img0).cpu(), Variable(img1).cpu())
    cov = torch.cat([output1, output2], dim=0).T @ torch.cat([output1, output2], dim=0)
    cov = torch.inverse(cov + 1e-6 * torch.eye(cov.shape[0]).to(output1.device))  # Add small regularization

    # Compute Mahalanobis distance
    diff = output1 - output2
    distance = torch.sqrt(torch.sum(torch.matmul(diff, cov) * diff, dim=1, keepdim=True))
    y_pred_now = [1 if d < threshold else 0 for d in distance]
    y_true_now = [label_tensor.item() for _, _, (label_tensor,) in zip(img0, img1, label)]

    if y_true is None:
        y_true = y_true_now
        y_pred = y_pred_now
    else:
        y_true.extend(y_true_now)
        y_pred.extend(y_pred_now)

    print(f"Iteration {i+1}")
   
    imshow(torchvision.utils.make_grid(merged), 'Dissimilarity: {:.2f}'.format(distance.item()))
    for pred, true in zip(y_pred, y_true):
        if pred == true:
            correct += 1
        total += 1
accuracy = accuracy_score(y_true, y_pred)
print(f"Accuracy: {accuracy:.2f}")
print("\nConfusion Matrix:\n", confusion_matrix(y_true, y_pred))
print("\nClassification Report:\n", classification_report(y_true, y_pred))
# Out:
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Iteration 6
# Iteration 7
# Iteration 8
# Iteration 9
# Iteration 10
# Accuracy: 0.70
#
# Confusion Matrix:
#  [[3 2]
#  [1 4]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.75      0.60      0.67         5
#          1.0       0.67      0.80      0.73         5
#
#     accuracy                           0.70        10
#    macro avg       0.71      0.70      0.70        10
# weighted avg       0.71      0.70      0.70        10
